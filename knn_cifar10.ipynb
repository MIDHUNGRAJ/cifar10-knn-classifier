# %%
import numpy as np 
import matplotlib.pyplot as plt

from torchvision.datasets import CIFAR10
from torchvision import transforms

transform = transforms.ToTensor()

# Train Data
trainset = CIFAR10(
    root = "./data",
    train=True,
    download=True,
    transform=transform
)

# Test Data
testset = CIFAR10(
    root="./data",
    train=False,
    download=True,
    transform=transform
)

# %%
X_train = trainset.data   # (50000, 32, 32, 3)
y_train = np.array(trainset.targets)

X_test = testset.data     # (10000, 32, 32, 3)
y_test = np.array(testset.targets)

print(X_train.shape)
print(X_test.shape)

# %%
num_train = 500 
num_test = 5

Xtr = X_train[:num_train]
ytr = y_train[:num_train]

Xte = X_test[:num_test]
yte = y_test[:num_test]

# %%
# Reshaping 32*32*3 = 3072
Xtr_flat = Xtr.reshape(num_train, -1)
Xte_flat = Xte.reshape(num_test, -1)

# %%
# KNN Model
class NearestNeighbor:

    def train(self, X, y):
        self.Xtr = X
        self.ytr = y

    def predict(self, X):

        num_test = X.shape[0]
        Ypred = np.zeros(num_test, dtype=self.ytr.dtype)
        nearest_idx = np.zeros(num_test, dtype=int)
        for i in range(num_test):

            distances = np.sum(
                np.abs(self.Xtr - X[i, :]),
                axis=1
            )

            min_index = np.argmin(distances)

            Ypred[i] = self.ytr[min_index]
            nearest_idx[i] = min_index

        return Ypred, nearest_idx

# %%
nn = NearestNeighbor()
nn.train(Xtr_flat, ytr)

pred, min_idx = nn.predict(Xte_flat)

print("pred:", pred)
print("true:", yte)

# %%
# Calculate Distance and return index
def find_nearest(Xtr, Xte):
    distance = np.sum(
        np.abs(Xtr - Xte),
        axis=1
    )

    return np.argmin(distance)

# %%
# Visualization

i = 4

plt.figure(figsize=(6,3))

plt.subplot(1, 2, 1)
plt.title("Test data")
plt.imshow(Xte[i])
plt.axis("off")

plt.subplot(1,2,2)
plt.title("Nearest")
plt.imshow(Xtr[min_idx[i]])
plt.axis("off")

plt.show()

# %%
pred

# %%
Xtr.shape, Xtr_flat.shape

# %% [markdown]
# ## Sklearn KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier()

model.fit(Xtr_flat, ytr)

# %%
y_pred = model.predict(Xte_flat)

# %%
y_pred

# %%
indices = model.kneighbors(Xte_flat, return_distance=False)

# %%
indices

# %%
i = 4

nearst_idx = indices[i][0]

plt.figure(figsize=(6,3))

plt.subplot(1, 2, 1)
plt.title("Test data")
plt.imshow(Xte[i])
plt.axis("off")

plt.subplot(1,2,2)
plt.title("Nearest")
plt.imshow(Xtr[nearst_idx])
plt.axis("off")

plt.show()
